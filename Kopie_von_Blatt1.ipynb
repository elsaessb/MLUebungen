# %% [markdown]
# # **AUFGABE 1**

# %% [markdown]
# Import **dependencies**.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
# %load_ext version_information

# %% [markdown]
# **Download** dataset.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
cols = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','TGT']
boston = pd.read_csv(url, sep=' ', skipinitialspace=True, header=None, names=cols, index_col=False)

# %% [markdown]
# Show **dataframe**.

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT   TGT
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Show **datatypes**.

# %%
boston.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# TGT        float64
# dtype: object

# %% [markdown]
# Check if a value is missing.

# %%
boston.isna().any()
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# TGT        False
# dtype: bool

# %% [markdown]
# Check if a row is contained multiple times in the dataframe.

# %%
boston.duplicated().any()
# Out:
# False

# %% [markdown]
# ...

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Create **scatter** - matrix.

# %%
pd.plotting.scatter_matrix(boston, figsize=(16, 16), marker='A')
# Out:
# array([[<AxesSubplot:xlabel='CRIM', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='NOX', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='RM', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='AGE', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='DIS', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='RAD', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='TAX', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='PTRATIO', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='B', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='CRIM'>,
#         <AxesSubplot:xlabel='TGT', ylabel='CRIM'>],
#        [<AxesSubplot:xlabel='CRIM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='INDUS', ylabel='ZN'>,
#         <AxesSubplot:xlabel='CHAS', ylabel='ZN'>,
# ...

# %% [markdown]
# Show boxplot.

# %%
pd.DataFrame.boxplot(boston, figsize=(15, 15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # **AUFGABE 2**

# %% [markdown]
# Kategorische Variablen sind: **CHAS** und **RAD**.

# %%
for subset in boston:
  print(f'{subset} - {len(boston[subset].unique())}')
# Out:
# CRIM - 504
# ZN - 26
# INDUS - 76
# CHAS - 2
# NOX - 81
# RM - 446
# AGE - 356
# DIS - 412
# RAD - 9
# TAX - 66
# PTRATIO - 46
# B - 357
# LSTAT - 455
# TGT - 229

# %%
boston.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# Folgende Kategorien / Variablen eigenen siche am besten zur vorhersage des **Hauspreises**.
#
# *   **LSTAT**
# *   **RM**
# *   **INDUS**

# %% [markdown]
# Correlation zwischen einzelnen Variablen größer als 0.5 oder kleiner als -0.5:

# %%
boston.corr() > 0.5
# Out:
#           CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# CRIM      True  False  False  False  False  False  False  False   True   True
# ZN       False   True  False  False  False  False  False   True  False  False
# INDUS    False  False   True  False   True  False   True  False   True   True
# CHAS     False  False  False   True  False  False  False  False  False  False
# NOX      False  False   True  False   True  False   True  False   True   True
# RM       False  False  False  False  False   True  False  False  False  False
# AGE      False  False   True  False   True  False   True  False  False   True
# DIS      False   True  False  False  False  False  False   True  False  False
# RAD       True  False   True  False   True  False  False  False   True   True
# TAX       True  False   True  False   True  False   True  False   True   True
# PTRATIO  False  False  False  False  False  False  False  False  False  False
# ...

# %%
boston.corr() < -0.5
# Out:
#           CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# CRIM     False  False  False  False  False  False  False  False  False  False
# ZN       False  False   True  False   True  False   True  False  False  False
# INDUS    False   True  False  False  False  False  False   True  False  False
# CHAS     False  False  False  False  False  False  False  False  False  False
# NOX      False   True  False  False  False  False  False   True  False  False
# RM       False  False  False  False  False  False  False  False  False  False
# AGE      False   True  False  False  False  False  False   True  False  False
# DIS      False  False   True  False   True  False   True  False  False   True
# RAD      False  False  False  False  False  False  False  False  False  False
# TAX      False  False  False  False  False  False  False   True  False  False
# PTRATIO  False  False  False  False  False  False  False  False  False  False
# ...

# %% [markdown]
# LSTAT ist mit INDUS und RM Korreliert.
# INDUS ist mit LSTAT Korreliert.
# RM ist mit LSTAT Korreliert.
#
# Daher könnte man INDUS und RM weglassen, da die beiden Variablen durch LSTAT sehr gut abgebildet werden.

# %%
# %version_information pandas, numpy, matplotlib
# Out:
# Software versions
# Python 3.9.7 64bit [GCC 7.5.0]
# IPython 7.27.0
# OS Linux 5.11.0 38 generic x86_64 with glibc2.31
# pandas 1.3.3
# numpy 1.21.2
# matplotlib 3.4.2
# Wed Oct 27 20:17:02 2021 CEST
